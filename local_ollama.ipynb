# %%
from langchain.tools.retriever import create_retriever_tool
from langchain_ollama import ChatOllama
from langchain.agents import AgentExecutor, create_openai_functions_agent
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from ipynb.fs.full.seed_data import seed_milus, connect_to_milvus
from langchain_community.callbacks.streamlit import StreamlitCallbackHandler
from langchain_community.chat_message_histories import StreamlitChatMessageHistory
from langchain.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever
from langchain_core.documents import Document
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 from langchain.agents import AgentExecutor, create_openai_functions_agent
#       4 from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
# ----> 5 from ipynb.fs.full.seed_data import seed_milus, connect_to_milvus
#       6 from langchain_community.callbacks.streamlit import StreamlitCallbackHandler
#       7 from langchain_community.chat_message_histories import StreamlitChatMessageHistory
#
# File ~/Desktop/python/STokyo/seed_data.ipynb:10
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 33,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import os\n",
# ---> 10     "import json\n",
#      11     "from uuid import uuid4\n",
#      12     "from dotenv import load_dotenv\n",
#      13     "from ipynb.fs.full.crawl import craw_web\n",
#      14     "from langchain_milvus import Milvus\n",
#      15     "from langchain_ollama import OllamaEmbeddings\n",
#      16     "from langchain.schema import Document"
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "code",
#      21    "execution_count": 34,
#      22    "metadata": {},
#      23    "outputs": [
#      24     {
#      25      "data": {
#      26       "text/plain": [
#      27        "True"
#      28       ]
#      29      },
#      30      "execution_count": 34,
#      31      "metadata": {},
#      32      "output_type": "execute_result"
#      33     }
#      34    ],
#      35    "source": [
#      36     "load_dotenv()"
#      37    ]
#      38   },
#      39   {
#      40    "cell_type": "code",
#      41    "execution_count": 35,
#      42    "metadata": {},
#      43    "outputs": [],
#      44    "source": [
#      45     "def load_data_from_local(filename: str, directory: str) -> tuple:\n",
#      46     "    file_path = os.path.join(directory, file_path)\n",
#      47     "    with open(file_path, 'r') as file:\n",
#      48     "        data = json.load(file)\n",
#      49     "    print(f'Data loaded from {file_path}')\n",
#      50     "    \n",
#      51     "    return data, filename.rsplit('.', 1)[0].replace('_', ' ')"
#      52    ]
#      53   },
#      54   {
#      55    "cell_type": "code",
#      56    "execution_count": 36,
#      57    "metadata": {},
#      58    "outputs": [],
#      59    "source": [
#      60     "def seed_milvus(URI_link: str, collection_name: str, filename: str, directory: str, use_ollama: bool = False) -> Milvus:\n",
#      61     "    if use_ollama: \n",
#      62     "        embedding = OllamaEmbeddings(model=\"llama3\")\n",
#      63     "    \n",
#      64     "    local_data, doc_name = load_data_from_local(filename, directory)\n",
#      65     "    \n",
#      66     "    documents = [\n",
#      67     "        Document(\n",
#      68     "            page_content=doc.get('page_content') or '',\n",
#      69     "            metadata={\n",
#      70     "                'source': doc['metadata'].get('source') or '',\n",
#      71     "                'content_type': doc['metadata'].get('content_type') or 'text/plain',\n",
#      72     "                'title': doc['metadata'].get('title') or '',\n",
#      73     "                'description': doc['metadata'].get('description') or '',\n",
#      74     "                'language': doc['metadata'].get('language') or 'en',\n",
#      75     "                'doc_name': doc_name,\n",
#      76     "                'start_index': doc['metadata'].get('start_index') or 0\n",
#      77     "            }\n",
#      78     "        )\n",
#      79     "        for doc in local_data\n",
#      80     "    ]\n",
#      81     "    \n",
#      82     "    print('documents: ', documents)\n",
#      83     "    \n",
#      84     "    uuids = [str(uuid4()) for _ in range(len(documents))]\n",
#      85     "    \n",
#      86     "    vectorstore = Milvus(\n",
#      87     "        embedding_function=embedding,\n",
#      88     "        connection_args={\"uri\": URI_link},\n",
#      89     "        collection_name=collection_name,\n",
#      90     "        drop_old=True\n",
#      91     "    )\n",
#      92     "    \n",
#      93     "    vectorstore.add_documents(documents=documents, ids=uuids)\n",
#      94     "    print('vector: ', vectorstore)\n",
#      95     "    return vectorstore\n",
#      96     "    "
#      97    ]
#      98   },
#      99   {
#     100    "cell_type": "code",
#     101    "execution_count": 37,
#     102    "metadata": {},
#     103    "outputs": [],
#     104    "source": [
#     105     "def seed_milvus_live(URL: str, URI_link: str, collection_name: str, doc_name: str, use_ollama: bool = False) -> Milvus:\n",
#     106     "    if use_ollama: \n",
#     107     "        embedding = OllamaEmbeddings(model = \"llama3\")\n",
#     108     "    \n",
#     109     "    documents = craw_web(URL)\n",
#     110     "    \n",
#     111     "    for doc in documents:\n",
#     112     "        metadata={\n",
#     113     "            'source': doc['metadata'].get('source') or '',\n",
#     114     "            'content_type': doc['metadata'].get('content_type') or 'text/plain',\n",
#     115     "            'title': doc['metadata'].get('title') or '',\n",
#     116     "            'description': doc['metadata'].get('description') or '',\n",
#     117     "            'language': doc['metadata'].get('language') or 'en',\n",
#     118     "            'doc_name': doc_name,\n",
#     119     "            'start_index': doc['metadata'].get('start_index') or 0\n",
#     120     "        }\n",
#     121     "        doc.metadata = metadata\n",
#     122     "    \n",
#     123     "    uuids = [str(uuid4()) for _ in range(len(documents))]\n",
#     124     "    \n",
#     125     "    vectorstore = Milvus(\n",
#     126     "        embedding_function=embedding,\n",
#     127     "        connection_args={\"uri\": URI_link},\n",
#     128     "        collection_name=collection_name,\n",
#     129     "        drop_old=True\n",
#     130     "    )\n",
#     131     "    \n",
#     132     "    vectorstore.add_documents(documents=documents, ids=uuids)\n",
#     133     "    print('vector: ', vectorstore)\n",
#     134     "    return vectorstore"
#     135    ]
#     136   },
#     137   {
#     138    "cell_type": "code",
#     139    "execution_count": 38,
#     140    "metadata": {},
#     141    "outputs": [],
#     142    "source": [
#     143     "def connect_to_milvus(URI_link: str, collection_name: str) -> Milvus:\n",
#     144     "    embedding = OllamaEmbeddings(model=\"llama3\")\n",
#     145     "    vectorstore = Milvus(\n",
#     146     "        embedding_function=embedding, \n",
#     147     "        connection_args={\"uri\": URI_link},\n",
#     148     "        collection_name=collection_name\n",
#     149     "    )\n",
#     150     "    return vectorstore"
#     151    ]
#     152   },
#     153   {
#     154    "cell_type": "code",
#     155    "execution_count": 39,
#     156    "metadata": {},
#     157    "outputs": [],
#     158    "source": [
#     159     "#def main():\n",
#     160     "    #seed_milvus('http://localhost:19530', 'data_test', 'titech.json', 'data', use_ollama=False)\n",
#     161     "    # # seed_milvus_live('https://www.owc.titech.ac.jp', 'http://localhost:19530', 'data_test_live', 'titech-ai', use_ollama=False)\n"
#     162    ]
#     163   },
#     164   {
#     165    "cell_type": "code",
#     166    "execution_count": 40,
#     167    "metadata": {},
#     168    "outputs": [],
#     169    "source": [
#     170     "#if __name__ == '__main__':\n",
#     171     "    #main()"
#     172    ]
#     173   }
#     174  ],
#     175  "metadata": {
#     176   "kernelspec": {
#     177    "display_name": "Python 3 (ipykernel)",
#     178    "language": "python",
#     179    "name": "python3"
#     180   }
#     181  },
#     182  "nbformat": 4,
#     183  "nbformat_minor": 2
#     184 }
#
# File ~/Desktop/python/STokyo/crawl.ipynb:17
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import os\n",
#      10     "import re\n",
#      11     "import json\n",
#      12     "from langchain_community.document_loaders import RecursiveUrlLoader, WebBaseLoader\n",
#      13     "from langchain_text_splitters import RecursiveCharacterTextSplitter\n",
#      14     "from bs4 import BeautifulSoup"
#      15    ]
#      16   },
# ---> 17   {
#      18    "cell_type": "code",
#      19    "execution_count": 42,
#      20    "metadata": {},
#      21    "outputs": [],
#      22    "source": [
#      23     "from fake_useragent import UserAgent\n",
#      24     "\n",
#      25     "os.environ['USER_AGENT'] = UserAgent().chrome"
#      26    ]
#      27   },
#      28   {
#      29    "cell_type": "code",
#      30    "execution_count": 43,
#      31    "metadata": {},
#      32    "outputs": [
#      33     {
#      34      "data": {
#      35       "text/plain": [
#      36        "True"
#      37       ]
#      38      },
#      39      "execution_count": 43,
#      40      "metadata": {},
#      41      "output_type": "execute_result"
#      42     }
#      43    ],
#      44    "source": [
#      45     "load_dotenv()"
#      46    ]
#      47   },
#      48   {
#      49    "cell_type": "code",
#      50    "execution_count": 44,
#      51    "metadata": {},
#      52    "outputs": [],
#      53    "source": [
#      54     "def bs4_extractor(html: str) -> str:\n",
#      55     "    soup = BeautifulSoup(html, \"html.parser\")\n",
#      56     "    return re.sub(r\"\\n\\n+\", \"\\n\\n\", soup.text).strip()"
#      57    ]
#      58   },
#      59   {
#      60    "cell_type": "code",
#      61    "execution_count": 45,
#      62    "metadata": {},
#      63    "outputs": [],
#      64    "source": [
#      65     "def craw_web(url_data):\n",
#      66     "    loader = RecursiveUrlLoader(url=url_data, extractor=bs4_extractor, max_depth=4)\n",
#      67     "    docs = loader.load()\n",
#      68     "    print('length: ', len(docs))\n",
#      69     "    \n",
#      70     "    text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=500)\n",
#      71     "    all_splitts = text_splitter.split_documents(docs)\n",
#      72     "    print('length_all_splits: ', len(all_splitts))\n",
#      73     "    return all_splitts"
#      74    ]
#      75   },
#      76   {
#      77    "cell_type": "code",
#      78    "execution_count": 46,
#      79    "metadata": {},
#      80    "outputs": [],
#      81    "source": [
#      82     "def web_base_loader(url_data):\n",
#      83     "    loader = WebBaseLoader(url_data)\n",
#      84     "    docs = loader.load()\n",
#      85     "    print('length: ', len(docs))\n",
#      86     "    \n",
#      87     "    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=500)\n",
#      88     "    all_splitts = text_splitter.split_documents(docs)\n",
#      89     "    return all_splitts"
#      90    ]
#      91   },
#      92   {
#      93    "cell_type": "code",
#      94    "execution_count": 47,
#      95    "metadata": {},
#      96    "outputs": [],
#      97    "source": [
#      98     "def save_data_locally(documments, filename, directory):\n",
#      99     "    if not os.path.exists(directory):\n",
#     100     "        os.makedirs(directory)\n",
#     101     "        \n",
#     102     "    file_path = os.path.join(directory, filename)\n",
#     103     "    \n",
#     104     "    data_to_save = [{'page_content': doc.page_content, 'metadata': doc.metadata} for doc in documments]\n",
#     105     "    \n",
#     106     "    with open(file_path, 'w') as file:\n",
#     107     "        json.dump(data_to_save, file, indent=4)\n",
#     108     "    print(f'Data saved to {file_path}')"
#     109    ]
#     110   },
#     111   {
#     112    "cell_type": "code",
#     113    "execution_count": 48,
#     114    "metadata": {},
#     115    "outputs": [],
#     116    "source": [
#     117     "#def main():\n",
#     118     "    #data = craw_web('https://www.ocw.titech.ac.jp/')\n",
#     119     "    \n",
#     120     "    #ave_data_locally(data, 'titech.json', 'web_data')\n",
#     121     "    #print('data: ', data)"
#     122    ]
#     123   },
#     124   {
#     125    "cell_type": "code",
#     126    "execution_count": 49,
#     127    "metadata": {},
#     128    "outputs": [],
#     129    "source": [
#     130     "#if __name__ == \"__main__\":\n",
#     131     "    #main()"
#     132    ]
#     133   }
#     134  ],
#     135  "metadata": {
#     136   "kernelspec": {
#     137    "display_name": "Python 3 (ipykernel)",
#     138    "language": "python",
#     139    "name": "python3"
#     140   },
#     141   "language_info": {
#     142    "codemirror_mode": {
#     143     "name": "ipython",
#     144     "version": 3
#     145    },
#     146    "file_extension": ".py",
#     147    "mimetype": "text/x-python",
#     148    "name": "python",
#     149    "nbconvert_exporter": "python",
#     150    "pygments_lexer": "ipython3",
#     151    "version": "3.13.0"
#     152   }
#     153  },
#     154  "nbformat": 4,
#     155  "nbformat_minor": 2
#     156 }
#
# NameError: name 'load_dotenv' is not defined
